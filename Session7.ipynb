# %% [markdown]
# **Feature Scalling**
# - Feature scalling is a method ,to modify the value either increase or decrease
#
# - in ML we have different column
#
#   - age range between 0 to 100
#
#   - height range between 0 to 200cm
#
#   - income range between 10k to 1 cr
#
# - different column having different range of values also different units
#
# - ML models might be think leads to more impact
#
# - Distance based algorithems are need to scale
#
# - Deep learning main aim is lower the error:**Convergence**
#
# **Standard Scalar**
#
#   - Zscale
#
#   - 99.7 of data lies between -3 to 3
#
#   - Mainly used in ML
#
# **MinMaxscalar**
#
#   - Normalization
#
#   - all the data lies between 0 to 1
#
#   - Mainly used in images scaling
#
#   - Generally color image values 0 to 255 R G B channel
#
#   - Gray images ranges 0 to 1,0 means Black 1 means White
#
# **Z scale**

# %% [markdown]
# <div class="iholder" id="yui_3_5_1_1_1777522535189_1174"><img src="https://nichea.sourceforge.net/images/figures/functions/standardization/formula1.png" id="img" style="width: 250px; height: 92px;"></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
visa_df=pd.read_csv(r'C:\Users\HP\Documents\Data_File\Visadataset.csv')
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
wage_data=visa_df['prevailing_wage']
wage_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
mean=np.mean(wage_data)
mean
# Out:
# np.float64(74455.81459209183)

# %%
std=np.std(wage_data)
std
# Out:
# 52814.90589711402

# %%
nr=wage_data-mean
nr
# Out:
#        prevailing_wage
# 0        -73863.611692
# 1          8969.835408
# 2         48541.045408
# 3          8978.215408
# 4         75451.575408
# ...                ...
# 25475      2636.755408
# 25476    204718.975408
# 25477     71843.035408
# 25478     11698.955408
# 25479     -3578.904592
#
# [25480 rows x 1 columns]

# %%
z_data=nr/std
z_data
# Out:
#        prevailing_wage
# 0            -1.398537
# 1             0.169835
# 2             0.919079
# 3             0.169994
# 4             1.428604
# ...                ...
# 25475         0.049924
# 25476         3.876159
# 25477         1.360280
# 25478         0.221509
# 25479        -0.067763
#
# [25480 rows x 1 columns]

# %%
plt.figure(figsize=(9,4))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(z_data)
plt.subplot(2,2,3).boxplot(wage_data)
plt.subplot(2,2,4).boxplot(z_data)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
visa_df=pd.read_csv(r'C:\Users\HP\Documents\Data_File\Visadataset.csv')
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
wage_data=visa_df[['prevailing_wage']]

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
sd.fit_transform(visa_df[['prevailing_wage']])
# Out:
# array([[-1.39853722],
#        [ 0.1698353 ],
#        [ 0.91907852],
#        ...,
#        [ 1.36027953],
#        [ 0.22150859],
#        [-0.06776315]], shape=(25480, 1))

# %%
plt.figure(figsize=(10,4))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(z_data)
plt.subplot(2,2,3).boxplot(wage_data)
plt.subplot(2,2,4).boxplot(z_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d6b26da90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d6b26dd10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d6b26d950>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d6b26df90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d6b26e0d0>],
#  'means': []}

# %% [markdown]
# **Normalization**
#  - using scratch
#    - read the wage data
#    - calculate min and max
#  - using pacakge
#    - sklearn
#     - preprocessing
#       - MinMaxScalar

# %%
wage_data=visa_df[['prevailing_wage']]
min=np.min(wage_data)
max=np.max(wage_data)
nr=wage_data-min
dr=max-min
nor=nr/dr
nor
# Out:
#        prevailing_wage
# 0             0.001849
# 1             0.261345
# 2             0.385312
# 3             0.261371
# 4             0.469616
# ...                ...
# 25475         0.241505
# 25476         0.874579
# 25477         0.458311
# 25478         0.269895
# 25479         0.222033
#
# [25480 rows x 1 columns]

# %%
plt.figure(figsize=(9,4))
plt.subplot(2,2,1).hist(nor)
plt.subplot(2,2,2).boxplot(nor)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d6b528410>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d6b528690>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d6b5282d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d6b528910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d6b528a50>],
#  'means': []}

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
ms.fit_transform(visa_df[['prevailing_wage']])
# Out:
# array([[0.00184853],
#        [0.2613452 ],
#        [0.385312  ],
#        ...,
#        [0.45831136],
#        [0.26989486],
#        [0.22203311]], shape=(25480, 1))

# %%
plt.figure(figsize=(9,4))
plt.subplot(2,2,1).hist(nor)
plt.subplot(2,2,2).boxplot(nor)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d6d33d810>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d6d33da90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d6d33d6d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d6d33dd10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d6d33de50>],
#  'means': []}
