# %% [markdown]
# **Import**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.__version__
# Out:
# '2.4.2'

# %% [markdown]
# **Rdataead the data**
# - visa data
# - Bank data

# %%
pd.read_csv(r'C:\Users\HP\Documents\Data_File\Visadataset.csv')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r'C:\Users\HP\Documents\Data_File\Visadataset.csv')

# %%
# viewing the data
visa_df.head()
visa_df.tail()
visa_df.sample()
visa_df.shape
visa_df.columns
visa_df.index
visa_df.values
#Data information
visa_df.info()
visa_df.describe()
visa_df.describe(include='all')
visa_df.dtypes
# Selection and indexing
visa_df.loc[]
visa_df.iloc[]

visa_df.at[]
visa_df.iat[]
#Aggregation Functions
visa_df.sum()
visa_df.mean()
visa_df.median()
visa_df.min()
visa_df.max()
visa_df.std()
visa_df.count()
#Missing Values
visa_df.isnull()
visa_df.notnull()
visa_df.dropna()
visa_df.fillna()
# Out:
#   Cell In[27], line 15
#     visa_df.loc[]
#                 ^
# SyntaxError: invalid syntax

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.index
# Out:
# RangeIndex(start=0, stop=25480, step=1)

# %%
visa_df.values
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.dtypes() # not callable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 visa_df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
data_types=visa_df.dtypes
type(data_types)
# Out:
# pandas.core.series.Series

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **series**
# - series is a ky value pair
# - series kind of a dictionary

# %%
data_types.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
data_types.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
data_types.index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
data_types.keys()
data_types.values
##################################
data_types.index
data_types.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %% [markdown]
# - when we have a series
# - we need to make to separate lists
# - so that we can able to create a dataframe

# %%
visa_df #df
visa_df.dtypes # type series
keys=visa_df.dtypes.keys() # keys
values=visa_df.dtypes.values # values
df1=pd.DataFrame(zip(keys,values),
                columns=['Visa data','Data type'])
df1
# Out:
#                 Visa data Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# **task**
# - separate cat and num column in different list
# - using dtypes

# %%
# idea
# extreact keys and values
# apply the for loop
# check the condition if the data type= odject then
# append in cat list
# otherwise append in num list
keys=visa_df.dtypes.keys() 
values=visa_df.dtypes.values
cat,num=[],[]
for i,j in zip(keys,values):
    print(i,j)
    if j=='object':
        cat.append(i)
    else:
        cat.append(i)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# prevailing_wage float64
# unit_of_wage object
# full_time_position object
# case_status object

# %%
visa_df.iloc[100:105,3:7] #df
visa_df.iloc[100] #s
visa_df.iloc[[100]] #df
visa_df.iloc[[100,200,300],]#df
visa_df.iloc[[100,200,300],:] #df
visa_df.iloc[:,[3,6,9]] #df
visa_df.iloc[:,3] #s
visa_df.iloc[:,[3]] #df
visa_df.iloc[:,:] #d

# %%
visa_df.iloc[100:105,3:7]
# Out:
#     has_job_experience requires_job_training  no_of_employees  yr_of_estab
# 100                  Y                     N             2227         2007
# 101                  Y                     N              334         2007
# 102                  Y                     N              224         2008
# 103                  Y                     N              367         1982
# 104                  Y                     N              306         2003

# %%
visa_df.iloc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa_df.iloc[[100,200,300],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[:,3]
# Out:
# 0        N
# 1        Y
# 2        N
# 3        N
# 4        Y
#         ..
# 25475    Y
# 25476    Y
# 25477    Y
# 25478    Y
# 25479    Y
# Name: has_job_experience, Length: 25480, dtype: object

# %%
visa_df.loc[:,]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - Bank Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv(r"C:\Users\HP\Documents\Data_File\bank.csv",sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df=pd.read_csv(r"C:\Users\HP\Documents\Data_File\bank.csv",sep=';')

# %%
bank_df.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %%
bank_df.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
bank_df.tail(2)
# Out:
#       age           job  marital  education default  balance housing loan  \
# 4519   28   blue-collar  married  secondary      no     1137      no   no
# 4520   44  entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
bank_df.shape
# Out:
# (4521, 17)

# %%
bank_df.size
# Out:
# 76857

# %%
bank_df.isnull()
# Out:
#         age    job  marital  education  default  balance  housing   loan  \
# 0     False  False    False      False    False    False    False  False
# 1     False  False    False      False    False    False    False  False
# 2     False  False    False      False    False    False    False  False
# 3     False  False    False      False    False    False    False  False
# 4     False  False    False      False    False    False    False  False
# ...     ...    ...      ...        ...      ...      ...      ...    ...
# 4516  False  False    False      False    False    False    False  False
# 4517  False  False    False      False    False    False    False  False
# 4518  False  False    False      False    False    False    False  False
# 4519  False  False    False      False    False    False    False  False
# 4520  False  False    False      False    False    False    False  False
#
#       contact    day  month  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
bank_df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 bank_df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
bank_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
data_types=bank_df.dtypes
type(data_types)
# Out:
# pandas.core.series.Series

# %%
type(bank_df)
# Out:
# pandas.core.frame.DataFrame

# %%
bank_df #df
bank_df.dtypes # type series
keys=bank_df.dtypes.keys() # keys
values=bank_df.dtypes.values # values
df1=pd.DataFrame(zip(keys,values),
                columns=['Bank data','Data type'])
df1
# Out:
#     Bank data Data type
# 0         age     int64
# 1         job    object
# 2     marital    object
# 3   education    object
# 4     default    object
# 5     balance     int64
# 6     housing    object
# 7        loan    object
# 8     contact    object
# 9         day     int64
# 10      month    object
# 11   duration     int64
# 12   campaign     int64
# 13      pdays     int64
# 14   previous     int64
# 15   poutcome    object
# 16          y    object
